# %%
#importing required Package
import pandas as pd
import seaborn as sns

# %%
#Reading the file
df = pd.read_csv("E:\APythonSoftware_2025\KaggelMachineLearning\KaggelCodes\Wine_Quality_Data.csv")

# %%
#displaying the First 5 rows in dataset
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
#checking for missing values
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df.shape
# Out:
# (6497, 13)

# %%
#checking for duplicates
df[df.duplicated()]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 6427            6.4             0.230         0.35           10.30      0.042
# 6449            7.0             0.360         0.35            2.50      0.048
# 6450            6.4             0.330         0.44            8.90      0.055
# 6455            7.1             0.230         0.39           13.70      0.058
# 6479            6.6             0.340         0.40            8.10      0.046
#
# ...

# %%
#removing the duplicates()
df.drop_duplicates(inplace=True)

# %%
#checking for duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [fixed_acidity, volatile_acidity, citric_acid, residual_sugar, chlorides, free_sulfur_dioxide, total_sulfur_dioxide, density, pH, sulphates, alcohol, quality, color]
# Index: []

# %%
df.shape
# Out:
# (5320, 13)

# %%
df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.214752     0.330328
# volatile_acidity           0.214752          1.000000    -0.384192
# citric_acid                0.330328         -0.384192     1.000000
# residual_sugar            -0.104439         -0.163696     0.146189
# chlorides                  0.288918          0.367626     0.055199
# free_sulfur_dioxide       -0.281590         -0.349039     0.130849
# total_sulfur_dioxide      -0.327471         -0.400716     0.194835
# density                    0.478180          0.308452     0.094758
# pH                        -0.271182          0.246687    -0.344735
# sulphates                  0.304844          0.227772     0.059183
# alcohol                   -0.102573         -0.065411    -0.005496
# quality                   -0.080092         -0.265205     0.097954
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))  # Adjust width and height as needed

sns.heatmap(df.corr(), annot=True, cmap="YlGnBu", ax=ax)

plt.show()

# %%
sample = df["residual_sugar"].sample(frac=0.05)
sample
# Out:
# 2988    0.90
# 5866    2.30
# 875     2.80
# 462     2.55
# 821     2.10
#         ...
# 4518    8.75
# 1153    2.10
# 4578    7.90
# 2885    1.80
# 88      2.10
# Name: residual_sugar, Length: 266, dtype: float64

# %%
from scipy import stats

# %%
t_test, p_value = stats.ttest_1samp(sample,df["residual_sugar"].mean())
t_test,p_value
# Out:
# (-0.1314026380769216, 0.8955565065155718)

# %%
if p_value < 0.05:
    print("h0 rejected,ha accepted, data is not properly distributed")
else:
    print("ha rejected, h0 accepted, data is properly distributed")
# Out:
# ha rejected, h0 accepted, data is properly distributed

# %%
for I in range(0,31):
    sample = df["residual_sugar"].sample(frac=0.05)
    t_test, p_value = stats.ttest_1samp(sample,df["residual_sugar"].mean())
    print(t_test,p_value)
    if p_value < 0.05:
        print("h0 rejected,ha accepted, data is not properly distributed")
    else:
        print("ha rejected, h0 accepted, data is properly distributed")
# Out:
# -0.6844518936293246 0.4942880057057817
# ha rejected, h0 accepted, data is properly distributed
# 0.7711567113532645 0.44130108921290323
# ha rejected, h0 accepted, data is properly distributed
# -1.030713336896045 0.30361505649926845
# ha rejected, h0 accepted, data is properly distributed
# 0.9178509056171854 0.35953153199728605
# ha rejected, h0 accepted, data is properly distributed
# -2.0163180846090007 0.04477558258982526
# h0 rejected,ha accepted, data is not properly distributed
# 0.9158780114108503 0.36056356255986766
# ha rejected, h0 accepted, data is properly distributed
# -0.7018155367237708 0.48341011916952437
# ha rejected, h0 accepted, data is properly distributed
# 0.0838433909381602 0.9332442496800241
# ha rejected, h0 accepted, data is properly distributed
# 0.19542289065171908 0.8452116531867726
# ha rejected, h0 accepted, data is properly distributed
# 0.5186282430033118 0.6044528002581846
# ha rejected, h0 accepted, data is properly distributed
# ...
